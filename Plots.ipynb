# %%
age_x=[25,26,27,29,33,32,35,28,35,39]
devop=[3525,3326,3627,3129,3633,3032,3115,3628,3435,3009]
javadop=[4525,5326,5627,5129,5633,5032,6115,6628,6435,6009]
plt.plot(age_x,devop,label="All devep")
plt.plot(age_x,javadop,label="All Java ")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.legend()
from matplotlib import pyplot as plt
plt.style.available

# %%
from matplotlib import pyplot as plt
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
age_x=sorted([25,26,27,29,33,32,35,28,35,39])

devop=sorted([3525,3326,3627,3129,3633,3032,3115,3628,3435,3009])
javadop=sorted([4525,5326,5627,5129,5633,5032,6115,6628,6435,6009])
plt.plot(age_x,devop,label="All devep")
plt.plot(age_x,javadop,label="All Java ")
plt.xlabel("Ages")
plt.ylabel("Median Salary (USD)")
plt.legend()

# %%
##Line Plot
age_x=sorted([25,26,27,29,33,32,35,28,35,39])

plt.plot(age_x, linestyle = 'dotted')
plt.ylabel("Ages")
plt.show()

# %%
#Scatter Plot
plt.scatter(devop,javadop)
plt.xlabel("Devop Salary")
plt.ylabel("Java Developer Salary")

plt.show()

# %%
##Histogramplt.

plt.hist(devop)
plt.xlabel("Devop Salary")
plt.show()
